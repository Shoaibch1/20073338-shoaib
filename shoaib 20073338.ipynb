# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Agriculture land aera data set dataset
agr= pd.read_csv('/content/Agriculture.csv')

# %%
#start from column 4
agr=agr.iloc[4:]

# %%
#show the table
agr.head()
# Out:
#                   Country Name Country Code  \
# 4                        Aruba          ABW
# 5  Africa Eastern and Southern          AFE
# 6                  Afghanistan          AFG
# 7   Africa Western and Central          AFW
# 8                       Angola          AGO
#
#                        Indicator Name  Indicator Code  1960       1961  \
# 4  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  11.111111
# 5  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  43.672679
# 6  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  57.745918
# 7  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  33.441755
# 8  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  45.857063
#
#         1962       1963       1964       1965  ...       2012       2013  \
# 4  11.111111  11.111111  11.111111  11.111111  ...  11.111111  11.111111
# 5  43.645948  43.681124  43.651032  43.622251  ...  43.621913  43.747682
# ...

# %%
#skips the 1st 4 columns of the table for year
agr_year=agr.iloc[:,4:]

# %%
#show the table of year
agr_year.head()
# Out:
#    1960       1961       1962       1963       1964       1965       1966  \
# 4   NaN  11.111111  11.111111  11.111111  11.111111  11.111111  11.111111
# 5   NaN  43.672679  43.645948  43.681124  43.651032  43.622251  43.647096
# 6   NaN  57.745918  57.837821  57.914407  58.010906  58.013969  58.072175
# 7   NaN  33.441755  33.557985  33.814094  33.942227  34.208301  33.937354
# 8   NaN  45.857063  45.881126  45.897169  45.921232  45.937274  45.961338
#
#         1967       1968       1969  ...       2012       2013       2014  \
# 4  11.111111  11.111111  11.111111  ...  11.111111  11.111111  11.111111
# 5  43.655131  43.689406  43.744262  ...  43.621913  43.747682  43.877935
# 6  58.173268  58.174800  58.199308  ...  58.067580  58.067580  58.067580
# 7  34.155213  34.255260  34.873514  ...  39.514961  39.740192  39.765147
# 8  45.985401  46.009465  46.041550  ...  43.011249  43.456474  43.901699
#
#         2015       2016       2017       2018  2019  2020  2021
# ...

# %%
#tranpose the year columns
agr_year.T
# Out:
#             4          5          6          7          8          9    \
# 1960        NaN        NaN        NaN        NaN        NaN        NaN
# 1961  11.111111  43.672679  57.745918  33.441755  45.857063  44.963504
# 1962  11.111111  43.645948  57.837821  33.557985  45.881126  44.963504
# 1963  11.111111  43.681124  57.914407  33.814094  45.897169  45.000000
# 1964  11.111111  43.651032  58.010906  33.942227  45.921232  44.890511
# ...         ...        ...        ...        ...        ...        ...
# 2017  11.111111  44.042629  58.067580  39.930699  45.237371  42.670839
# 2018  11.111111  44.117980  58.081365  39.953545  45.682594  42.849672
# 2019        NaN        NaN        NaN        NaN        NaN        NaN
# 2020        NaN        NaN        NaN        NaN        NaN        NaN
# 2021        NaN        NaN        NaN        NaN        NaN        NaN
#
#             10         11        12         13   ...        260        261  \
# ...

# %%
#finding the sum of year at zero axis
sum_of_agr_year=agr_year.sum(axis=0)
sum_of_agr_year
# Out:
# 1960       0.000000
# 1961    7922.749241
# 1962    7931.156236
# 1963    7966.797365
# 1964    7986.620284
#            ...
# 2017    9581.793287
# 2018    9578.527843
# 2019       0.000000
# 2020       0.000000
# 2021       0.000000
# Length: 62, dtype: float64

# %%
#assign new variable to insert in to new col
agr_year_land=pd.DataFrame(sum_of_agr_year)
agr_year_land
# Out:
#                 0
# 1960     0.000000
# 1961  7922.749241
# 1962  7931.156236
# 1963  7966.797365
# 1964  7986.620284
# ...           ...
# 2017  9581.793287
# 2018  9578.527843
# 2019     0.000000
# 2020     0.000000
# 2021     0.000000
#
# [62 rows x 1 columns]

# %%
#drop the NAN fromt he table
agr_year_land=agr_year_land.dropna()
agr_year_land
# Out:
#                 0
# 1960     0.000000
# 1961  7922.749241
# 1962  7931.156236
# 1963  7966.797365
# 1964  7986.620284
# ...           ...
# 2017  9581.793287
# 2018  9578.527843
# 2019     0.000000
# 2020     0.000000
# 2021     0.000000
#
# [62 rows x 1 columns]

# %%
#change the data type of the  float to int
agr_year_land['year']=agr_year_land.index.astype('int')
agr_year_land
# Out:
#                 0  year
# 1960     0.000000  1960
# 1961  7922.749241  1961
# 1962  7931.156236  1962
# 1963  7966.797365  1963
# 1964  7986.620284  1964
# ...           ...   ...
# 2017  9581.793287  2017
# 2018  9578.527843  2018
# 2019     0.000000  2019
# 2020     0.000000  2020
# 2021     0.000000  2021
#
# [62 rows x 2 columns]

# %%
#data type check
agr_year_land.dtypes
# Out:
# 0       float64
# year      int64
# dtype: object

# %%
#ploting
plt.figure(figsize=(8,5))
plt.plot(agr_year_land['year'],agr_year_land[0])
plt.title('Total Agriculture land per year')
plt.xlabel('Year')
plt.ylabel('Total Agriculture area')
plt.show()

# %%
#now plotting the countries name code or 1998 year
agr_country_1998=agr[['Country Name','Country Code','1998']]

# %%
agr_country_1998
# Out:
#                     Country Name Country Code       1998
# 4                          Aruba          ABW  11.111111
# 5    Africa Eastern and Southern          AFE  42.106997
# 6                    Afghanistan          AFG  58.001716
# 7     Africa Western and Central          AFW  36.768123
# 8                         Angola          AGO  37.419232
# ..                           ...          ...        ...
# 265                       Kosovo          XKX        NaN
# 266                  Yemen, Rep.          YEM  44.851033
# 267                 South Africa          ZAF  80.775540
# 268                       Zambia          ZMB  29.627786
# 269                     Zimbabwe          ZWE  37.533928
#
# [266 rows x 3 columns]

# %%
#selected the some countries
agr_country_code_1998=['CHN','USA','PAK','AFG','RUS','GBR']

# %%
#country name and code with area land in 1998
agr_year_country_1998=agr_country_1998[agr_country_1998['Country Code'].isin(agr_country_code_1998)]
agr_year_country_1998
# Out:
#            Country Name Country Code       1998
# 6           Afghanistan          AFG  58.001716
# 44                China          CHN  55.570781
# 85       United Kingdom          GBR  72.409375
# 188            Pakistan          PAK  47.685762
# 206  Russian Federation          RUS  13.264332
# 255       United States          USA  45.265838

# %%
#PLOTTING 1998 area land
fig, ax = plt.subplots(figsize=(9,4))
sns.barplot(x="Country Name", y="1998", data=agr_year_country_1998)
ax.set_title("Agriculture land(%) by Country name",fontdict= {'size':12})
ax.xaxis.set_label_text("Countries",fontdict= {'size':12})
ax.yaxis.set_label_text("Land Area(%) in 1998",fontdict= {'size':12})
plt.show()

# %%
#now plotting the countries name code or 2018 year
agr_country_2018=agr[['Country Name','Country Code','2018']]

# %%
#table of 2018 countries with area land
agr_country_2018
# Out:
#                     Country Name Country Code       2018
# 4                          Aruba          ABW  11.111111
# 5    Africa Eastern and Southern          AFE  44.117980
# 6                    Afghanistan          AFG  58.081365
# 7     Africa Western and Central          AFW  39.953545
# 8                         Angola          AGO  45.682594
# ..                           ...          ...        ...
# 265                       Kosovo          XKX        NaN
# 266                  Yemen, Rep.          YEM  44.297403
# 267                 South Africa          ZAF  79.417850
# 268                       Zambia          ZMB  32.063923
# 269                     Zimbabwe          ZWE  41.876696
#
# [266 rows x 3 columns]

# %%
#selected the countries 
agr_country_code_2018=['CHN','USA','PAK','AFG','RUS','GBR']

# %%
#print the chart of the selected countries and the land area in 2018
agr_year_country_2018=agr_country_2018[agr_country_2018['Country Code'].isin(agr_country_code_2018)]
agr_year_country_2018
# Out:
#            Country Name Country Code       2018
# 6           Afghanistan          AFG  58.081365
# 44                China          CHN  56.079083
# 85       United Kingdom          GBR  71.718520
# 188            Pakistan          PAK  47.089041
# 206  Russian Federation          RUS  13.158436
# 255       United States          USA  44.363367

# %%
#plotting
fig, ax = plt.subplots(figsize=(9,4))
sns.barplot(x="Country Name", y="2018", data=agr_year_country_2018)
ax.set_title("Agriculture land(%) by Country name",fontdict= {'size':12})
ax.xaxis.set_label_text("Countries",fontdict= {'size':12})
ax.yaxis.set_label_text("Land Area(%) in 2018",fontdict= {'size':12})
plt.show()
